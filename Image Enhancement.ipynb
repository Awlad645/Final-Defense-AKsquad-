# %%
image = cv2.imread('/content/result.png',0) 
equ_image = cv2.equalizeHist(image)
cv2_imshow(segmented_image)
cv2_imshow(equ_image)
# Out:
# <PIL.Image.Image image mode=L size=2110x1240 at 0x7F5D91F81A00>
# <PIL.Image.Image image mode=L size=2110x1240 at 0x7F5D91F816A0>
